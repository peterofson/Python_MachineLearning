# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)
tr_path = '/Users/Stellarhardwood/Downloads/Assignment 1 - datasets/train.csv'
test_path = '/Users/Stellarhardwood/Downloads/Assignment 1 - datasets/test.csv'
data = pd.read_csv(tr_path)

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
sweet = data.columns
len(sweet)
# Out:
# 81

# %%
Y = data['SalePrice']
X = data['GrLivArea']

plt.scatter(X,Y, marker ="x")

plt.title("Sales Price vs Living Area (excluding basement)")
plt.xlabel("GrLivArea")
plt.ylabel("SalePrice");

# %%
data.plot('YearBuilt', 'SalePrice', kind = 'scatter', marker= 'x')

# %%
def inverse_of_matrix(mat):
    square_matrix = np.array(mat)
    matrix_inverse = np.linalg.inv(square_matrix)
    return matrix_inverse

# %%
print("test",inverse_of_matrix([[1,2],[3,4]]), "\n")
# Out:
# test [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
print("From Data:\n", inverse_of_matrix(data.iloc[:2,:2]))
# Out:
# From Data:
#  [[-0.2   0.6 ]
#  [ 0.02 -0.01]]

# %%
### In order to create any model it is necessary to read in data
### Build a function called "read_to_df" that takes the file_path of a .csv file.
### Use a pandas functions appropriate for .csv files to turn that path into a DataFrame
### Use pandas function defaults for reading in file
### Return that DataFrame
### Grade will be determined by whether or not the returned item is of type "DataFrame" and
### if the dimensions are correct
import pandas as pd
def read_to_df(file_path):
    csv_data = pd.read_csv(file_path)
    data_frame = pd.DataFrame(csv_data)
    return data_frame

# %%
read_to_df('/Users/Stellarhardwood/Downloads/Assignment 1 - datasets/train.csv')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
### Build a function called "select_columns"
### As inputs, take a DataFrame and a *list* of column names.
### Return a DataFrame that only has the columns specified in the list of column names
### Grading will check type of object, dimensions of object, and column names
### YOUR ANSWER BELOW
import pandas as pd
def select_columns(data_frame, column_names):
    subdf = data_frame[column_names]
    return subdf

# %%
this_lists = ['SalePrice', 'LotArea', 'YrSold']
select_columns(data,this_lists)
# Out:
#       SalePrice  LotArea  YrSold
# 0        208500     8450    2008
# 1        181500     9600    2007
# 2        223500    11250    2008
# 3        140000     9550    2006
# 4        250000    14260    2008
# 5        143000    14115    2009
# 6        307000    10084    2007
# 7        200000    10382    2009
# 8        129900     6120    2008
# 9        118000     7420    2008
# 10       129500    11200    2008
# 11       345000    11924    2006
# 12       144000    12968    2008
# 13       279500    10652    2007
# 14       157000    10920    2008
# 15       132000     6120    2007
# 16       149000    11241    2010
# 17        90000    10791    2006
# 18       159000    13695    2008
# 19       139000     7560    2009
# 20       325300    14215    2006
# 21       139400     7449    2007
# 22       230000     9742    2008
# 23       129900     4224    2007
# 24       154000     8246    2010
# 25       256300    14230    2009
# 26       134800     7200    2010
# ...

# %%
### Build a function called "column_cutoff"
### As inputs, accept a Pandas Dataframe and a list of tuples.
### Tuples in format (column_name, min_value, max_value)
### Return a DataFrame which excludes rows where the value in specified column exceeds "max_value"
### or is less than "min_value"
### ### NB: DO NOT remove rows if the column value is equal to the min/max value
def column_cutoff(data_frame, cutoffs):
    
    mytuples = []
    lg = len(cutoffs)
    count = 0
    update_frame = data_frame.copy()
    
    while (count <= lg):
        for x in cutoffs:
            sub_tuples = x
            mytuples.append(tuple(sub_tuples))
        label = mytuples[count][0]
        min_value = mytuples[count][1]
        max_value = mytuples[count][2]
        update_frame = update_frame.loc[(update_frame[label] <= max_value) & (update_frame[label] >= min_value)]                
        
        count=count+1
                
            
    return update_frame

# %%
cuts = [('SalePrice', 200000, 1e8), ('LotArea', 0, 4000), ('YrSold', 2006, 2009)]
test_data = column_cutoff(data,cuts)
test_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 559    560         120       RL          NaN     3196   Pave   NaN      Reg
# 639    640         120       RL         53.0     3982   Pave   NaN      Reg
# 851    852         120       RL          NaN     3196   Pave   NaN      Reg
# 1019  1020         120       RL         43.0     3013   Pave   NaN      Reg
# 1405  1406         120       RM         44.0     3842   Pave   NaN      IR1
#
#      LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature  \
# 559          Lvl    AllPub    ...            0    NaN   NaN         NaN
# 639          Lvl    AllPub    ...            0    NaN   NaN         NaN
# 851          Lvl    AllPub    ...            0    NaN   NaN         NaN
# 1019         Lvl    AllPub    ...            0    NaN   NaN         NaN
# 1405         HLS    AllPub    ...            0    NaN   NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...
